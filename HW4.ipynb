# %%
#W4A1
sum = 0
i = 1
while i <= 1000:
    sum += i
print(sum)

# %%
#W4A3
x = int(input(''))
goal = 1
while x != 1:
    goal *= x
    x -= 1
print(goal)
# Out:
#  9
# 362880

# %%
#W4A4
n = int(input(""))
n = abs(n)
x = 0
while n != 0:
    x += 1
    n //= 10
print(x)
# Out:
#  234
# 3

# %%
#W4A6
a = int(input())
b = int(input())
x = 0
while b !=a:
    if nt(b):
        x += b
    x -= 1
print(x)

# %%
#W4A7
n = int(input())
x = n
n -= 1
while n > 0:
    if x%n == 0 and nt(n):
        print(n)
        break
    n -= 1
# Out:
#  6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 n -= 1
#       5 while n > 0:
# ----> 6     if t%n == 0 and nt(n):
#       7         print(n)
#       8         break
#
# NameError: name 'nt' is not defined

# %%
#W4A11
n = int(input(""))
a = 0
b = 0
while a <n:
    if a %2==0:
        b+=1
    a+=1
print(b)
# Out:
#  56
# 28

# %%
#W4A12
x = int(input(""))
n = int(input(""))
print(x*((1+r)**n))

# %%
#W4A15
a = int(input(""))
b = int(input(""))
g = (4*a-b)/2
c = a-g
if g >= 0 and c >= 0:
    print(g,c)
else:
    print("invalid")
# Out:
#  24
#  30
# invalid
